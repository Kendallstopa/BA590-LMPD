# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
import shapefile
import matplotlib.patches as patches
import matplotlib.pyplot as plt

# %%
# Using Target table with "Y" values beacuse we are dealing with categorical data 
df2 = pd.read_csv('ImputedData', index_col=0)
df2.head()
# Out:
#    ID       TYPE_OF_STOP CITATION_CONTROL_NUMBER  ACTIVITY RESULTS  \
# 0   1  TRAFFIC VIOLATION                       0                 0
# 1   2  TRAFFIC VIOLATION                       0                 0
# 2   3  TRAFFIC VIOLATION                       0                 0
# 3   4  TRAFFIC VIOLATION                       0                 0
# 4   5  TRAFFIC VIOLATION                       0                 0
#
#   OFFICER_GENDER OFFICER_RACE OFFICER_AGE_RANGE        ACTIVITY_DATE  \
# 0              M        WHITE           40 - 50  2015-01-24 00:00:00
# 1              M        WHITE           40 - 50  2015-01-30 00:00:00
# 2              M        WHITE           40 - 50  2016-09-20 00:00:00
# 3              F        WHITE           21 - 30  2016-01-22 00:00:00
# 4              F        WHITE           21 - 30  2015-09-14 00:00:00
#
#          ACTIVITY_TIME                                  ACTIVITY_LOCATION  \
# ...

# %%
r = shapefile.Reader('KentuckyZipCodes')

# %%
myshp = open('KentuckyZipCodes.shp', 'rb')
mydbf = open('KentuckyZipCodes.dbf', 'rb')
r = shapefile.Reader(shp=myshp, dbf=mydbf)

# %%
import urllib.request
import zipfile
from io import BytesIO

# %%
sf = shapefile.Reader("KentuckyZipCodes")  
 
shape_recs = sf.shapeRecords()
 
fig = plt.figure(figsize = (40,20))
#fig.set_size_inches(40.5, 20.5, forward=True)

ax = fig.add_subplot(111)
 
for rec in shape_recs:
    points = rec.shape.points
    d = rec.record  # record MetaData
    zip_code = d[2]
    c=(0.9, 0.2, 0.5, 0.2)

    
    if zip_code == "40212":  # Coloring in 1 zipcode
        c='blue'
    patch = patches.Polygon(points,True,label=d[2], color=c, alpha=0.09)
    ax.add_patch(patch)
    
    if zip_code == "40211":  # Coloring in 1 zipcode
        c='red'
    patch = patches.Polygon(points,True,label=d[2], color=c)
    ax.add_patch(patch)
    
    if zip_code == "40258":  # Coloring in 1 zipcode
        c='green'
    patch = patches.Polygon(points,True,label=d[2], color=c)
    ax.add_patch(patch)
    
    if zip_code == "40208":  # Coloring in 1 zipcode
        c='yellow'
    patch = patches.Polygon(points,True,label=d[2], color=c)
    ax.add_patch(patch)
    
    if zip_code == "40205":  # Coloring in 1 zipcode
        c='purple'
    patch = patches.Polygon(points,True,label=d[2], color=c)
    ax.add_patch(patch)
    
    if zip_code == "40228":  # Coloring in 1 zipcode
        c='black'
    patch = patches.Polygon(points,True,label=d[2], color=c)
    ax.add_patch(patch)
    
ax.autoscale()


plt.axis('off')


plt.show()
